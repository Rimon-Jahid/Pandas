# %%
#install pandas
# !pip install pandas

# %%
#import panda
import pandas as pd

# %%
# creat a list
data = [1,2,3,4,5]
data
type(data)
# Out:
# list

# %%
#create a series
series = pd.Series(data)
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#creat a dataframe by series
dataframe = pd.DataFrame(series,columns = ['num'])
dataframe
# Out:
#    num
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
#dataframe from data
dataframe2 = pd.DataFrame(data,columns = ['num'])
dataframe2
# Out:
#    num
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
#series from dataframe
series2 = dataframe2['num']
series2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: num, dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
#creat dataframe from 2d data
data = [[1,2],[3,4],[5,6]]
dataframe3 = pd.DataFrame(data,columns = ['num1','num2'])
dataframe3
# Out:
#    num1  num2
# 0     1     2
# 1     3     4
# 2     5     6

# %%
#create a series from 2d dataframe 
series3 = dataframe3[['num1','num2']]
series3
# Out:
#    num1  num2
# 0     1     2
# 1     3     4
# 2     5     6

# %%
type(series3)
# Out:
# pandas.core.frame.DataFrame
