# %%
import pandas as pd

# %%
#creat dictionay by data
data = {
    'name' : ['Rimon','Jahid'],
    'age' : [21,23],
    'location' : ['Dhaka','Khagan']
}
data
# Out:
# {'name': ['Rimon', 'Jahid'], 'age': [21, 23], 'location': ['Dhaka', 'Khagan']}

# %%
#creat series from dictionary
series = pd.Series(data)
series
# Out:
# name         [Rimon, Jahid]
# age                [21, 23]
# location    [Dhaka, Khagan]
# dtype: object

# %%
#creat series from dictionary
series = pd.Series([data['name'],data['age'],data['location']])
series
# Out:
# 0     [Rimon, Jahid]
# 1           [21, 23]
# 2    [Dhaka, Khagan]
# dtype: object

# %%
series = pd.Series(data['name'])
series
# Out:
# 0    Rimon
# 1    Jahid
# dtype: object

# %%
#creat a dataframe from dictionary
dataframe = pd.DataFrame(data)
dataframe
# Out:
#     name  age location
# 0  Rimon   21    Dhaka
# 1  Jahid   23   Khagan

# %%
# creat a series from dataframe
name_series = dataframe['name']
name_series
# Out:
# 0    Rimon
# 1    Jahid
# Name: name, dtype: object
